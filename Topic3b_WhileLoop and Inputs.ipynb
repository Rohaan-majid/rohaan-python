# %%
name = "Rohaan"
print("your name is",name)
# Out:
# your name is Rohaan

# %%
name = input()
print("your name is",name.title())
# Out:
# your name is Qw23

# %%
# if user enter rohan print welcome rohaan else print hi <that name>
name = input()
if name.lower() == "rohaan":
    print(f"welcome {name}")
else:
    print(f"hello {name}")
# Out:
# welcome RoHaAN

# %%
# take an input from user if that number is positive ( means mroe than 0 ) print the number you entered is positive
# elif if number is negative print its negative


num1=input("enter a number")
num1 = int(num1)
if num1 >= 0:
    print("your number is positive")
else:
    print("your number is negative")
# Out:
# your number is positive

# %%
import random
number = random.randint(1,10)
print(number)
# Out:
# 6

# %%
# make a guessing game in which
# random number is amde from 1 to 3
# you ask user to enter his number
# if they same == means print match
# else print not match

# %%
computer=random.randint(1,3)
playerInput= int ( input("guess the number 1-3") )

if computer == playerInput:
    print("Match!you win")
else:
    print("wrong, you lose :(")
print(f"the number was {computer}")
print(f"your number was {playerInput}")
# Out:
# Match!you win
# the number was 2
# your number was 2

# %%
import random

# %%
import random
computer=random.randint(1,10)

while True:
    playerInput= int ( input("guess the number 1-3") )
    if computer == playerInput:
        print("Match!you win")
        break
    else:
        print("wrong, you lose :(")
        print(f"your {playerInput} did not match")

print(f"the number was {computer}")
# Out:
# wrong, you lose :(
# your 1 did not match
# wrong, you lose :(
# your 2 did not match
# wrong, you lose :(
# your 3 did not match
# wrong, you lose :(
# your 4 did not match
# wrong, you lose :(
# your 5 did not match
# wrong, you lose :(
# your 6 did not match
# wrong, you lose :(
# your 7 did not match
# wrong, you lose :(
# your 8 did not match
# wrong, you lose :(
# your 9 did not match
# Match!you win
# the number was 10

# %%
import random
computer=random.randint(1,500)
trial = 0
while True:
    playerInput= int ( input("guess the number 1-500"))
    if computer == playerInput:
        print("Match!you win")
        break
    elif computer>playerInput:
        print(f"wrongyour number is smaller increase it. your number was {playerInput} ")
    elif computer<playerInput:
        print(f"you number is bigger make it smaller.your number was {playerInput}")
    else:
        print("somethign not good")
    trial += 1

print(f"the number was {computer}")
print(f"you guessed it in {trial} trials")
# Out:
# wrongyour number is smaller increase it. your number was 6
# wrongyour number is smaller increase it. your number was 300
# you number is bigger make it smaller.your number was 500
# wrongyour number is smaller increase it. your number was 400
# you number is bigger make it smaller.your number was 450
# you number is bigger make it smaller.your number was 435
# you number is bigger make it smaller.your number was 428
# you number is bigger make it smaller.your number was 491
# wrongyour number is smaller increase it. your number was 419
# you number is bigger make it smaller.your number was 425
# wrongyour number is smaller increase it. your number was 420
# you number is bigger make it smaller.your number was 427
# you number is bigger make it smaller.your number was 422
# you number is bigger make it smaller.your number was 424
# you number is bigger make it smaller.your number was 423
# Match!you win
# the number was 421
# you guessed it in 15 trials

# %%
# make a rps list of rock paper and scissors
# random.choice (rps) you get a element from list randomly
# if same print draw
# if computer == "rock" and

# %%
import random
rps = ["rock","scissors","paper"]
computer= random.choice(rps)
player = input("rock paper or scissors") 
if computer == "rock" and player== "paper":
    print("you win, paper beats rock")
elif computer == "rock" and player== "scissors":
    print ("you lose, rock beats sccissors")
elif computer == "rock" and player== "rock":
    print ("draw")
elif computer == "paper" and player== "scissors":
    print ("you win,sccissors beats paper")
elif computer == "paper" and player== "rock":
    print ("you lose,rock beats paper")
elif computer == "paper" and player== "paper":
    print ("draw")
elif computer == "scissors" and player== "paper":
    print ("you lose,sccissors beats paper")
elif computer == "scissors" and player== "rock":
    print ("you win,rock beats scissors")
elif computer == "scissors" and player== "scissors":
    print ("draw")
print(f"bot played {computer}")
print(f"you played {player}")
# Out:
# you win,rock beats scissors
# scissors

# %%
import random
rps = ["rock","scissors","paper"]
computer= random.choice(rps)
player = input("rock paper or scissors") 
if computer == player:
    print("Draw")
elif computer == "rock" and player== "paper" or computer == "paper" and player== "scissors" or computer == "scissors" and player== "rock":
    print(f"you win, {player} beats {computer}")
elif computer == "rock" and player== "scissors" or computer == "rock" and player== "rock" or computer == "paper" and player== "rock":
    print (f"you lose, {computer} beats {player}")
else:
    print("you entereed wrong")


print(f"bot played {computer}")
print(f"you played {player}")
