# %% [markdown]
# # 1.  LIST

# %%
colors = ['red', 'orange', 'pink', 'yellow']
print(colors)
# Out:
# ['red', 'orange', 'pink', 'yellow']

# %%
friends= ['ahmed','ali','abdullah']
print(friends)
# Out:
# ['ahmed', 'ali', 'abdullah']

# %% [markdown]
# ## 1.1 access from list

# %%
friends[2]
# Out:
# 'abdullah'

# %%
friends[0]
# Out:
# 'ahmed'

# %% [markdown]
# ## 1.2 change

# %%
friends[0] = "AHmad"

# %%
friends
# Out:
# ['AHmad', 'ali', 'abdullah']

# %%
friends[1]="ALI"
friends[2]="ABDULLAH"

# %%
friends[0] = friends[0].upper()

# %%
friends
# Out:
# ['AHMAD', 'ALI', 'ABDULLAH']

# %% [markdown]
# ## 1.3 remove

# %%
del friends[2]

# %%
friends
# Out:
# ['AHMAD', 'ALI']

# %% [markdown]
# ## 1.4 add in list

# %%
friends.append("ABDULLAH")

# %%
friends
# Out:
# ['AHMAD', 'ALI', 'ABDULLAH']

# %%
friends.insert(2,"umer")

# %%
friends
# Out:
# ['AHMAD', 'ALI', 'umer', 'ABDULLAH']

# %%
### please make a Pizza flavor list
# change them to upper case
# remve all one by one

# %%
Flavours=['hawaiian','cheese','chicken','beef']
Flavours
Flavours[0]=Flavours[0].upper()
Flavours[1]=Flavours[1].upper()
Flavours[2]=Flavours[2].upper()
Flavours[3]=Flavours[3].upper()
Flavours
# Out:
# ['HAWAIIAN', 'CHEESE', 'CHICKEN', 'BEEF']

# %%
del Flavours[0]
print(Flavours)
del Flavours[0]
print(Flavours)
del Flavours[0]
print(Flavours)
# Out:
# ['CHEESE', 'CHICKEN', 'BEEF']
# ['CHICKEN', 'BEEF']
# ['BEEF']

# %%
Flavours.append("Chicken")
Flavours.append("bbq")
Flavours.append("mexican")
Flavours.append("hawaiin")

# %%
Flavours
# Out:
# ['BEEF', 'Chicken', 'bbq', 'mexican', 'hawaiin']

# %%
print("rohaan")
# Out:
# rohaan

# %%
msg = "hello you are invited to the party"
friends = ["rohaan", "abdullah", "ali", "ahmed"]
for f in friends:
    print(f"{f}, {msg}")
# Out:
# rohaan, hello you are invited to the party
# abdullah, hello you are invited to the party
# ali, hello you are invited to the party
# ahmed, hello you are invited to the party

# %% [markdown]
# ### make a list of fruits you like and print something like
# #### for example
# #### i like oranges

# %%
fruits = ["apple", "banana", "grape", "orange", "mango"]
for f in fruits:
    print(f"{f} is my favorite fruit")
# Out:
# apple is my favorite fruit
# banana is my favorite fruit
# grape is my favorite fruit
# orange is my favorite fruit
# mango is my favorite fruit

# %%
# we have to store populations
populations = {"New York": 8336817, "Los Angeles": 3979576, "Chicago": 2705994}

# %%
# access
populations["New York"]
# change
populations["New York"] =populations["New York"] + 100000
# remove 
del populations["Chicago"]
# add new city
populations["Houston"] = 2328000

# %%
print(populations)
# Out:
# {'New York': 8436817, 'Los Angeles': 3979576, 'Houston': 2328000}

# %%
fruits_prices = {"apple": 0.5, "banana": 0.25, "grape": 1.0, "orange": 0.75, "mango": 1.5}

# %%
fruits_prices["apple"]
fruits_prices["apple"]  = 0.8
print(fruits_prices)
# Out:
# {'apple': 0.8, 'banana': 0.25, 'grape': 1.0, 'orange': 0.75, 'mango': 1.5}

# %%
del fruits_prices["grape"]
print(fruits_prices)
# Out:
# {'apple': 0.8, 'banana': 0.25, 'orange': 0.75, 'mango': 1.5}

# %%
fruits_prices["kiwi"]=0.2
print(fruits_prices)
# Out:
# {'apple': 0.8, 'banana': 0.25, 'orange': 0.75, 'mango': 1.5, 'kiwi': 0.2}

# %%
fruits_prices.items()
# Out:
# dict_items([('apple', 0.8), ('banana', 0.25), ('orange', 0.75), ('mango', 1.5), ('kiwi', 0.2)])

# %%
fruits_prices.keys()
# Out:
# dict_keys(['apple', 'banana', 'orange', 'mango', 'kiwi'])

# %%
fruits_prices.values()
# Out:
# dict_values([0.8, 0.25, 0.75, 1.5, 0.2])
