# %% [markdown]
# # 1.  LIST

# %%
colors = ['red', 'orange', 'pink', 'yellow']
print(colors)

# %%
friends= ['ahmed','ali','abdullah']
print(friends)
# Out:
# ['ahmed', 'ali', 'abdullah']

# %% [markdown]
# ## 1.1 access from list

# %%
friends[2]
# Out:
# 'abdullah'

# %%
friends[0]
# Out:
# 'ahmed'

# %% [markdown]
# ## 1.2 change

# %%
friends[0] = "AHmad"

# %%
friends
# Out:
# ['AHmad', 'ali', 'abdullah']

# %%
friends[1]="ALI"
friends[2]="ABDULLAH"

# %%
friends[0] = friends[0].upper()

# %%
friends
# Out:
# ['AHMAD', 'ALI', 'ABDULLAH']

# %% [markdown]
# ## 1.3 remove

# %%
del friends[2]

# %%
friends
# Out:
# ['AHMAD', 'ALI']
