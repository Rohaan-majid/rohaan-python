# %% [markdown]
# ## Topic 1 - Data types

# %%
name = "Rohaan"
age = 13
height = 171.2
student = True

# %% [markdown]
# ### Topic 2 - Data Structure

# %%
person = [name,age,height,student,"learning python"]

# %% [markdown]
# #  Topic 3 -  Condtions

# %%
temp = 27
if temp >40:
    print("turn on fan")
else:
    print("turn off fan")
# Out:
# turn off fan

# %% [markdown]
# # topic 4 is loop

# %%
for i in range(5):
    print(name)
# Out:
# Rohaan
# Rohaan
# Rohaan
# Rohaan
# Rohaan
